# %%
import pandas as pd

# %%
suicidedata_df = pd.read_csv("data/master.csv")
suicidedata_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
renamed_suicidedata_df = suicidedata_df.rename(columns = {' gdp_for_year ($) ':'gdp_for_year',
                                                          'gdp_per_capita ($)':'gdp_per_capita',
                                                         'suicides/100k pop':'suicidesper100pop',
                                                         'HDI for year':'hdi_for_year'})
renamed_suicidedata_df['hdi_for_year'] = pd.to_numeric(renamed_suicidedata_df['hdi_for_year'], errors='coerce')
renamed_suicidedata_df['hdi_for_year'] = renamed_suicidedata_df['hdi_for_year'].fillna(0)
renamed_suicidedata_df["gdp_for_year"] = renamed_suicidedata_df["gdp_for_year"].str.replace(',', '')
renamed_suicidedata_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicidesper100pop    country-year  hdi_for_year gdp_for_year  \
# ...

# %%
cleaned_suicidedata = renamed_suicidedata_df.drop(columns=["country-year"])
cleaned_suicidedata
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicidesper100pop  hdi_for_year gdp_for_year  gdp_per_capita  \
# ...

# %%
# Interactive choropleth map with hover – by city and suicide number
# Line chart – number of suicides by age
# Bar chart – Top 10 countries by number of suicides
# Pie chart – Male vs Female suicide rate
# Scatter plot – check for correlation between GDP and number of suicides
# Scatter plot – Y- axis – beginning year of dataset, X-axis – ending year of our dataset

# %%
# https://stackoverflow.com/questions/23103962/how-to-write-dataframe-to-postgres-table#:~:text=to_sql%20method%20and%20you%20won,inserted%20in%20your%20postgres%20table.

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import inspect,create_engine, func

password = "secu:0502"
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/suicide_db')
# cleaned_suicidedata.to_sql('suicidedata', engine)

# %%
inspector = inspect(engine)
inspector.get_table_names() 
columns = inspector.get_columns('suicidedata')

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# []

# %%
data = pd.read_sql_query('SELECT * FROM suicidedata',con=engine)

# %%
results = engine.execute("SELECT country, SUM(suicides_no) AS suicides FROM suicidedata GROUP BY country ORDER BY suicides DESC")

output = {}
for result in results:
    output[result['country']] = int(result['suicides'])

# %%
print(output)
# Out:
# {'Russian Federation': 1209742, 'United States': 1034013, 'Japan': 806902, 'France': 329127, 'Ukraine': 319950, 'Germany': 291262, 'Republic of Korea': 261730, 'Brazil': 226613, 'Poland': 139098, 'United Kingdom': 136805, 'Italy': 132060, 'Mexico': 111139, 'Thailand': 110643, 'Canada': 107561, 'Kazakhstan': 101546, 'Spain': 100202, 'Argentina': 82219, 'Hungary': 73891, 'Romania': 72777, 'Australia': 70111, 'Belgium': 62761, 'Belarus': 59892, 'Sri Lanka': 55641, 'Colombia': 53080, 'Netherlands': 50833, 'Austria': 50073, 'Czech Republic': 43687, 'Cuba': 41418, 'Chile': 40895, 'Sweden': 37795, 'Bulgaria': 36388, 'Uzbekistan': 34803, 'Finland': 33677, 'Lithuania': 28039, 'Switzerland': 26217, 'Serbia': 24179, 'Portugal': 24061, 'Philippines': 21330, 'Ecuador': 20660, 'Croatia': 18429, 'Norway': 16992, 'Denmark': 15297, 'New Zealand': 14383, 'Slovakia': 13437, 'Uruguay': 13138, 'Kyrgyzstan': 13090, 'Latvia': 12770, 'Ireland': 12574, 'Greece': 12368, 'El Salvador': 11683, 'Israel': 11294, 
# ...

# %%
results = engine.execute("SELECT DISTINCT country, SUM(suicides_no) AS suicides, MAX(gdp_for_year) AS gdp_for_year FROM suicidedata WHERE year = 1985 GROUP BY country;")

output = {}
for result in results:
    output[result['country']] = {
            'suicides': int(result['suicides']),
            'gdp': result['gdp_for_year']
    }
print(output)
# Out:
# {'Antigua and Barbuda': {'suicides': 0, 'gdp': '240923926'}, 'Argentina': {'suicides': 1988, 'gdp': '88416668900'}, 'Australia': {'suicides': 1861, 'gdp': '180190994861'}, 'Austria': {'suicides': 2091, 'gdp': '69386774475'}, 'Bahamas': {'suicides': 1, 'gdp': '2320699900'}, 'Bahrain': {'suicides': 11, 'gdp': '3651861702'}, 'Barbados': {'suicides': 7, 'gdp': '1417575550'}, 'Belgium': {'suicides': 2281, 'gdp': '86730038793'}, 'Brazil': {'suicides': 4228, 'gdp': '222942790435'}, 'Bulgaria': {'suicides': 1456, 'gdp': '17155421053'}, 'Canada': {'suicides': 3258, 'gdp': '364756499451'}, 'Chile': {'suicides': 683, 'gdp': '17702885394'}, 'Colombia': {'suicides': 1001, 'gdp': '34894411352'}, 'Costa Rica': {'suicides': 128, 'gdp': '4796628461'}, 'Dominica': {'suicides': 0, 'gdp': '98585185'}, 'Ecuador': {'suicides': 393, 'gdp': '17149094590'}, 'France': {'suicides': 12501, 'gdp': '553138414367'}, 'Greece': {'suicides': 405, 'gdp': '47820850975'}, 'Grenada': {'suicides': 1, 'gdp': '167728444'}, 
# ...

# %%
results = engine.execute("SELECT year, sex, SUM(suicides_no) AS suicides FROM suicidedata GROUP BY year,sex;")
output = []
for result in results:
    yearly_result = {
        'year': result['year'],
        'sex': result['sex'],
        'suicides': int(result['suicides'])
    }
    output.append(yearly_result)

# %%
output
# Out:
# [{'year': 1990, 'sex': 'male', 'suicides': 143243},
#  {'year': 2009, 'sex': 'female', 'suicides': 54920},
#  {'year': 1990, 'sex': 'female', 'suicides': 50118},
#  {'year': 2013, 'sex': 'male', 'suicides': 171740},
#  {'year': 2008, 'sex': 'male', 'suicides': 181474},
#  {'year': 2014, 'sex': 'female', 'suicides': 51556},
#  {'year': 1999, 'sex': 'male', 'suicides': 199904},
#  {'year': 1994, 'sex': 'female', 'suicides': 51532},
#  {'year': 1985, 'sex': 'male', 'suicides': 83584},
#  {'year': 2000, 'sex': 'male', 'suicides': 200578},
#  {'year': 2016, 'sex': 'female', 'suicides': 3504},
#  {'year': 1988, 'sex': 'male', 'suicides': 88011},
#  {'year': 2006, 'sex': 'female', 'suicides': 52039},
#  {'year': 2002, 'sex': 'male', 'suicides': 200546},
#  {'year': 1989, 'sex': 'male', 'suicides': 118883},
#  {'year': 2003, 'sex': 'male', 'suicides': 200452},
#  {'year': 2001, 'sex': 'male', 'suicides': 197653},
#  {'year': 2010, 'sex': 'male', 'suicides': 184480},
# ...

# %%
# import itertools
# from operator import itemgetter
# sorted_output = sorted(output, key=itemgetter('year'))
    
# yearlylist=[]
# # Display data grouped by `class`
# for key, value in itertools.groupby(sorted_output, key=itemgetter('year')):
#     print (key)
#     for i in value:
#         print (i.get('sex'),i.get('suicides'))
#         yearlylist.append({
#             key:{
#                 i.get('sex'):i.get('suicides')
#             }
#         })
        #print(f'{key}:{{i.get('sex')}:{i.get('suicides')}}')
    
import itertools
from operator import itemgetter
yearly_results = {}
sorted_output = sorted(output, key=itemgetter('year'))
for key, group in itertools.groupby(sorted_output, key=lambda x:x['year']):
    yearly_results[key] = list(group)

# %%
output_results
# Out:
# {1985: [{'year': 1985, 'sex': 'male', 'suicides': 83584},
#   {'year': 1985, 'sex': 'female', 'suicides': 32479}],
#  1986: [{'year': 1986, 'sex': 'male', 'suicides': 86818},
#   {'year': 1986, 'sex': 'female', 'suicides': 33852}],
#  1987: [{'year': 1987, 'sex': 'male', 'suicides': 91836},
#   {'year': 1987, 'sex': 'female', 'suicides': 35006}],
#  1988: [{'year': 1988, 'sex': 'male', 'suicides': 88011},
#   {'year': 1988, 'sex': 'female', 'suicides': 33015}],
#  1989: [{'year': 1989, 'sex': 'male', 'suicides': 118883},
#   {'year': 1989, 'sex': 'female', 'suicides': 41361}],
#  1990: [{'year': 1990, 'sex': 'male', 'suicides': 143243},
#   {'year': 1990, 'sex': 'female', 'suicides': 50118}],
#  1991: [{'year': 1991, 'sex': 'female', 'suicides': 49622},
#   {'year': 1991, 'sex': 'male', 'suicides': 148398}],
#  1992: [{'year': 1992, 'sex': 'male', 'suicides': 159906},
#   {'year': 1992, 'sex': 'female', 'suicides': 51567}],
# ...

# %%
sorted_output
# Out:
# [{'year': 1985, 'sex': 'male', 'suicides': 83584},
#  {'year': 1985, 'sex': 'female', 'suicides': 32479},
#  {'year': 1986, 'sex': 'male', 'suicides': 86818},
#  {'year': 1986, 'sex': 'female', 'suicides': 33852},
#  {'year': 1987, 'sex': 'male', 'suicides': 91836},
#  {'year': 1987, 'sex': 'female', 'suicides': 35006},
#  {'year': 1988, 'sex': 'male', 'suicides': 88011},
#  {'year': 1988, 'sex': 'female', 'suicides': 33015},
#  {'year': 1989, 'sex': 'male', 'suicides': 118883},
#  {'year': 1989, 'sex': 'female', 'suicides': 41361},
#  {'year': 1990, 'sex': 'male', 'suicides': 143243},
#  {'year': 1990, 'sex': 'female', 'suicides': 50118},
#  {'year': 1991, 'sex': 'female', 'suicides': 49622},
#  {'year': 1991, 'sex': 'male', 'suicides': 148398},
#  {'year': 1992, 'sex': 'male', 'suicides': 159906},
#  {'year': 1992, 'sex': 'female', 'suicides': 51567},
#  {'year': 1993, 'sex': 'female', 'suicides': 51331},
#  {'year': 1993, 'sex': 'male', 'suicides': 170234},
# ...
